# %% [markdown]
# # All imports and inits

# %%
import pandas as pd
import glob
import concurrent.futures
import gradio as gr
import tkinter as tk
import streamlit as st
import numpy as np
import textwrap
import PyPDF2
import requests
import os
import pinecone
import time

from langchain.document_loaders.pdf import PyPDFDirectoryLoader
from dotenv import load_dotenv
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.schema.document import Document
from langchain.schema import AIMessage, HumanMessage, SystemMessage
from tkinter import scrolledtext, messagebox
from transformers import AutoModel, AutoTokenizer
from typing import List, Tuple
from openai import OpenAI
from pinecone import Pinecone, ServerlessSpec, CloudProvider, AwsRegion, VectorType

# NVidia Embedding import

client = OpenAI(
    api_key="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",
    base_url="https://integrate.api.nvidia.com/v1",
)

load_dotenv()

DATA_PATH = os.getenv("DATA_PATH")
PINECONE_API = os.getenv("PINECONE_API")
# PINECONE_ENV = os.getenv("PINECONE_ENV")
GROQ_API_KEY = os.getenv("GROQ_API_KEY")
print("PINECONE_API", PINECONE_API)
GROQ_CHAT_URL = "https://api.groq.com/openai/v1/chat/completions"  # for integrating groq via openai api method
# Configure headers for Groq API requests
GROQ_HEADERS = {
    "Authorization": f"Bearer {GROQ_API_KEY}",
    "Content-Type": "application/json",
}
# LLM_MODEL = "llama3-70b-8192"
LLM_MODEL = "llama-3.3-70b-versatile"
"""
Input:
    - Context window: 128K
Ouput:
    - Output Max Tokens: 32,768

"""

def track_time(func):
    def wrapper(*args, **kwargs):
        start = time.perf_counter()
        result = func(*args, **kwargs)
        end = time.perf_counter()
        print(f"[Time Tracker] `{func.__name__}` took {end - start:.4f} seconds")
        return result
    return wrapper
# # EMBEDDING_MODEL = "llama3-405b-8192-embed"

# vo = voyageai.Client()
# Out:
# PINECONE_API pcsk_2zBTsW_U5bfHyCathSYufEN1wYf1t3v9jtSX9T94Zqk3z8h7djMZFM324gKjpeoKKhkr4q

# %% [markdown]
# # Init Pinecone

# %%
pc = Pinecone(api_key=PINECONE_API)
print(PINECONE_API)
# Out:
# pcsk_2zBTsW_U5bfHyCathSYufEN1wYf1t3v9jtSX9T94Zqk3z8h7djMZFM324gKjpeoKKhkr4q

# %% [markdown]
# # Embedding Function

# %%
# Connect to the index
index = pc.Index("ai-coach")
# # index = pc.Index("ahsan-400pg-pdf-doc-test")

# embedding_model = AutoModel.from_pretrained(
#     'jinaai/jina-embeddings-v2-base-en', trust_remote_code=True)


# # Function to generate embeddings without tokenization
# def get_embedding(data):
#     embeddings = embedding_model.encode(data).tolist()
#     return embeddings

@track_time
def get_embedding(text="None"):
    response = client.embeddings.create(
        input=text,
        model="nvidia/nv-embed-v1",
        encoding_format="float",
        extra_body={"input_type": "query", "truncate": "NONE"},
    )

    #print(response.data[0].embedding)
    # print(count_tokens(response.data[0].embedding))
    return response.data[0].embedding
get_embedding("None")
# Out:
# [Time Tracker] `get_embedding` took 1.5830 seconds
# [-0.01506805419921875,
#  -0.01165008544921875,
#  0.02081298828125,
#  0.0252227783203125,
#  -0.0198211669921875,
#  0.011077880859375,
@track_time
def query_pinecone(embedding):
    # Use keyword arguments to pass the embedding and other parameters
    result = index.query(vector=embedding, top_k=1600, include_metadata=True)
    return result["matches"]

# %% [markdown]
# # Query Groq Inference

# %%
from groq import Groq
# Function to query Groq LLM
# def query_groq(prompt: str) -> str:
#     response = requests.post(
#         GROQ_CHAT_URL,
#         headers=GROQ_HEADERS,
#         json={
#             "model": LLM_MODEL,
#             "messages": [{"role": "user", "content": prompt}],
#             "temperature": 0.5,
#             # "max_tokens": 8192  # max from groq website
#         },
#     )

#     if response.status_code != 200:
#         raise Exception(f"Error querying Groq: {response.text}")

#     return response.json()["choices"][0]["message"]["content"]


# def query_groq(prompt: str) -> str:
#     client = Groq()
#     completion = client.chat.completions.create(
#         messages=[{"role": "user", "content": prompt}],
#         # Change model to compound-beta to use agentic tooling
#         # model: "llama-3.3-70b-versatile",
#         model=LLM_MODEL,
#     )
#     # print(completion.choices[0].message.content)
#     return completion.choices[0].message.content

@track_time
def query_groq(prompt: str) -> str:
    client = Groq()
    completion = client.chat.completions.create(
        messages=[{"role": "user", "content": prompt}],
        model=LLM_MODEL,
        temperature=0.5,  # Set temperature to 0.5
        )
    return completion.choices[0]


query_groq("Hello")
# Print all tool calls
# print(completion.choices[0].message.executed_tools)


# Tokenizer to count number of tokens

@track_time
def count_tokens(text: str) -> int:
    tokenizer = AutoTokenizer.from_pretrained("jinaai/jina-embeddings-v2-base-en")
    # Encode the text into tokens
    tokens = tokenizer.encode(text)
    return len(tokens)
# Out:
# [Time Tracker] `query_groq` took 2.3376 seconds

# %% [markdown]
# # Process User Query

# %% [markdown]
# ### Gradio GUI TEST

# %%
# ------------------------------------------- WORKING 3 Enter key submits user query -------------------------------------------
# Initialize empty conversation history (list of tuples)
conversation_history = []

@track_time
def process_user_query(user_query: str, conversation_history: list):
    print(f"User Query Tokens: {count_tokens(user_query)}")

    # Generate embedding and get relevant context
    embedding = get_embedding(user_query)
    relevant_chunks = query_pinecone(embedding)
    context = "\n".join(chunk["metadata"]["text"] for chunk in relevant_chunks)
    print("CONTEXT:", context)

    # Format conversation history for the prompt
    history_str = "\n".join(
        f"User: {user}\nCoach: {response}" for user, response in conversation_history
    )

    # Create structured prompt
    prompt = f"""You are an expert, knowledgeable, and friendly coach. Follow these guidelines carefully:

    1. Provide clear, step-by-step explanations to ensure deep understanding.
    2. Use chain-of-thought reasoning to thoroughly evaluate the provided context before responding.
    3. Ask guiding questions to encourage critical thinking.
    4. Adapt your explanation to match the student's knowledge level.
    5. Strictly use terminologies provided in the given context.
    6. Provide short, ideal examples (2-3) to illustrate your points clearly.
    7. Only answer based on the provided context—do not speculate or include external information.
    8. Explicitly cite the sources from the context in your responses.
    9. Perform sentiment analysis based on conversation history and user queries to adapt your responses empathetically and effectively.

    Context from learning materials:
    {context}

    Conversation history:
    {history_str}

    New student question:
    "{user_query}"

    Provide a helpful, structured response that meets the above criteria.

    (Note: The following examples are only provided for your reference to demonstrate an effective response format):

    Question: How long will the average externship take to complete?
    Answer: 125 surgical cases – typically 6 months to 1 year.

    Question: What should I focus on when studying anatomy, physiology, and medical terminology?
    Answer: Focus specifically on content related to surgical procedures, emphasizing body systems, terminology, and physiological functions most relevant to surgery.

    Question: What’s the best way to study and memorize surgical instrumentation?
    Answer: First, understand the National Center for Competency Testing (NCCT) exam expectations regarding instruments. Refer to official NCCT guidelines and utilize platforms such as Quizlet and ProProfs for visual memorization and repetition.

    Provide a thoughtful and contextually accurate response now:"""

    # --------------------- Reasoning Prompt --------------------------------------------------------------
    # prompt = f"""You are an expert, knowledgeable, and friendly coach. Follow this structured response framework:

    # ### Response Requirements
    # 1. **Reasoning Process**:
    # - Analyze the question against provided context
    # - Identify relevant context snippets with source citations
    # - Perform sentiment analysis on conversation history

    # 2. **Response Format**:
    # - [Understanding] Paraphrase the question to confirm comprehension
    # - [Relevant Context] Cite exact source material with location references
    # - [Step-by-Step Explanation] Break down concepts using chain-of-thought
    # - [Examples] Provide 2-3 ideal examples from context
    # - [Guiding Questions] Pose 1-2 reflective questions to deepen learning
    # - [Summary] Concise answer reiterating key points

    # 3. **Style Guidelines**:
    # - Use terminology strictly from context
    # - Adapt complexity to student's history
    # - Maintain empathetic tone based on sentiment analysis

    # ### Context Materials:
    # {context}

    # ### Conversation History:
    # {history_str}

    # ### New Question:
    # "{user_query}"

    # ### Your Response:
    # [Understanding] First, let me clarify what you're asking...
    # [Relevant Context] According to [Source X, Section Y]...
    # [Step-by-Step Explanation] The process works as follows:
    # 1. First concept...
    # 2. Second concept...
    # 3. Practical application...
    # [Examples] For instance:
    # - Example 1...
    # - Example 2...
    # [Guiding Questions] Have you considered...? How might this apply to...?
    # [Summary] To recap the key points..."""

    # Get LLM response
    groq_response = query_groq(prompt)
    print(f"Response Toke   ns: {count_tokens(groq_response.message.content)}")

    # Return updated history with new interaction
    return conversation_history + [(user_query, groq_response.message.content)]


# Gradio Interface
with gr.Blocks() as interface:
    gr.Markdown("# 🧑‍🏫 AI Coaching Assistant")
    gr.Markdown("Welcome! I'm here to help you learn. Type your question below.")

    # State management
    chat_history = gr.State(conversation_history)

    with gr.Row():
        chatbot = gr.Chatbot(height=500)
        with gr.Column(scale=0.5):
            context_display = gr.Textbox(label="Relevant Context", interactive=False)

    user_input = gr.Textbox(label="Your Question", placeholder="Type here...")

    with gr.Row():
        submit_btn = gr.Button("Submit", variant="primary")
        undo_btn = gr.Button("Undo Last")
        clear_btn = gr.Button("Clear History")

    def handle_submit(user_input, history):
        if not user_input.strip():
            return gr.update(), history, ""

        # Process query and update history
        new_history = process_user_query(user_input, history)

        # Get latest context for display
        latest_context = "\n".join(
            [
                chunk["metadata"]["text"]
                for chunk in query_pinecone(get_embedding(user_input))
            ][:]
        )  # Show top 3 context snippets

        return "", new_history, latest_context

    # Component interactions
    submit_btn.click(
        handle_submit,
        [user_input, chat_history],
        [user_input, chat_history, context_display],
    ).then(lambda x: x, [chat_history], [chatbot])

    # Add submit on Enter key press
    user_input.submit(
        handle_submit,
        [user_input, chat_history],
        [user_input, chat_history, context_display],
    ).then(lambda x: x, [chat_history], [chatbot])

    undo_btn.click(
        lambda history: history[:-1] if history else [], [chat_history], [chat_history]
    ).then(lambda x: x, [chat_history], [chatbot])

    clear_btn.click(lambda: [], None, [chat_history]).then(
        lambda: ([], ""), None, [chatbot, context_display]
    )

interface.launch(share=True)
# Out:
# C:\Users\ABC\AppData\Local\Temp\ipykernel_19596\102894957.py:118: UserWarning: You have not specified a value for the `type` parameter. Defaulting to the 'tuples' format for chatbot messages, but this is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style dictionaries with 'role' and 'content' keys.
#   chatbot = gr.Chatbot(height=500)
# D:\Disrupt Labs\AI Coach Project\Rag-pipelines-experiments\env\Lib\site-packages\gradio\layouts\column.py:55: UserWarning: 'scale' value should be an integer. Using 0.5 will cause issues.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://39f81c1afbbef4ff9a.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://39f81c1afbbef4ff9a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# [Time Tracker] `count_tokens` took 0.4520 seconds
# User Query Tokens: 4
# [Time Tracker] `get_embedding` took 1.2899 seconds
# [Time Tracker] `query_pinecone` took 7.0653 seconds
# CONTEXT: Medicolegal Aspects of
# Surgical Technology
# Bank Name: nan Question: The surgical consent is signed by the ________, __________, and a(n) ___________. Randomization (Yes/No): Yes Correct Answer Number: 3 Answer 1: Nurse, Surgeon, Scrub Feedback 1: nan Answer 2: Nurse, Surgeon, Anesthesiologist Feedback 2: nan Answer 3: Surgeon, Patient, Witness Feedback 3: nan Answer 4: Surgeon, Anesthesiologist, Nurse Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Course Name: Introduction to Surgical Technology File Name: Lesson - 01 Introduction to Surgical Technology
#  Topic: Introduction to Surgical Technology
#  Description: Explore the origins, training, and role of surgical technologists, the services provided by their professional association, career opportunities, and the ethics and behaviors defining the field. Keywords: Surgical Technology, Operating Room Technician, Surgical Assistant, AST, Certification, Surgical Ethics, Surgical Training, Professional Organizations, Career Opportunities, Surgical Conscience​
# Course Name: Introduction to Surgical Technology File Name: C1L3 Topic: Medicolegal aspects of surgical technology Description:  This lesson covers the medicolegal aspects of surgical technology, including federal and state laws, liability types, malpractice, informed consent, and patient rights. It highlights key policies, documentation requirements, and the importance of legal awareness in ensuring patient safety and professional accountability. Keywords: medicolegal, liability, malpractice, informed consent, patient rights, healthcare law, documentation, legal policies, professional accountability, surgical technology
# Course Name: Introduction to Surgical Technology File Name: C1L1 Topic: Surgical Technology: The profession and the professional Description: This lesson introduces the surgical technology profession, covering its history, professional organizations, and key responsibilities. It highlights perioperative roles, sterile field maintenance, and ethical considerations, emphasizing the importance of professional development, patient safety, and adherence to healthcare standards. Keywords: perioperative care, sterile field, surgical instruments, patient safety, professional organizations, ethical considerations, operating room, healthcare standards, surgical procedures
# Course Name: Introduction to Surgical Technology File Name: Lesson 03 - Medicolegal Aspects Of Surgical
# Technology
#  Topic: Medicolegal Aspects Of Surgical
# Technology
#  Description: Learn to distinguish between laws, standards, and codes of conduct, understand risk management, licensure, and certification, recognize abuse and violence, define sentinel
# events, and explore negligence, documentation, informed consent, and legal documents in the perioperative environment. Keywords: Medical Law, Surgical Negligence, Informed Consent, HIPAA, Patient Rights, Risk Management, Sentinel Events, Universal Protocol, Workplace Harassment, Documentation​
# Course Name: Introduction to Surgical Technology File Name: Chapter 03 (Medicolegal Aspects Of Surgical
# Technology)
#  Topic: Chapter 03: Medicolegal Aspects Of Surgical
# Technology
#  Description: Learn to distinguish between laws, standards, and codes of
# conduct, understand risk management, licensure, and
# certification, recognize abuse and violence, define sentinel
# events, and explore negligence, documentation, informed
# consent, and legal documents in the perioperative environment. Keywords: Medical Law, Surgical Negligence, Informed Consent, HIPAA, Patient Rights, Risk Management, Sentinel Events, Universal Protocol, Workplace Harassment, Documentation​
# Course Name: Introduction to Surgical Technology File Name: C1L5 Topic: Supporting the psychosocial needs of the patient Description: This lesson emphasizes the importance of addressing patients' psychosocial needs in surgery through empathy, active listening, and reassurance. It discusses common patient fears, the role of communication, and Maslow’s hierarchy of needs in understanding and supporting patients emotionally. Keywords: psychosocial needs, patient care, empathy, active listening, reassurance, Maslow’s hierarchy, surgical anxiety, therapeutic communication, patient fears, emotional support
# C1L5	-	Ashley	Hay
# (0:06	-	0:18)
# Welcome	back.	We	are	on	the	last	lesson	for	course	one.	So	course	one,	lesson	five,	we're
# gonna	look	at	supporting	the	psychosocial	needs	of	the	patient,	really	important.
# (0:19	-	0:50)
# And	as	a	surgical	tech,	you	really	contribute	to	the	patient's	wellbeing	overall.	So	not	only	do
# you	help	for	their	physical	health,	you	also	help	for	their	psychological	health	as	well.	So	just
# realising	that	while	this	is	your	job	and	you	show	up	every	day,	day	to	day	and	see	patients	in
# and	out	and	you	feel	it's	very	easy	and	normal,	just	kind	of	get	them	in	and	get	them	out	and
# everything	turns	out	great.
# (0:50	-	1:06)
# You	have	to	realise	that	for	this	patient,	it	is	very	much	a	traumatic	and	sometimes	a	life-
# changing	event.	And	always	remembering	that	these	patients	don't	want	to	be	there	per	se.
# And	just	put	yourself	in	their	shoes.
# (1:06	-	1:24)
# If	you	were	undergoing	a	surgery,	that	is	a	very	big	day	in	your	life.	And	you	have	a	lot	of	fears
# and	concerns	and	anxieties	and	hope	for	different	kinds	of	outcomes.	So	it's	really	just	always
# practising	empathy	and	compassion.
# (1:25	-	1:55)
# And	even	if	you	show	up	every	day	to	this	job	for	years	and	years,	it's	always	remembering	that
# for	this	patient,	it	is	a	really	big	deal.	And	they	don't	see	the	setting	the	same	way	that	you	do	as
# a	provider.	So	it's	really	just	kind	of	recognising	that	everybody	is	incredibly	unique	and
# patients	have	all	different	kinds	of	physical	and	social	and	psychosocial	needs.
# (1:57	-	2:15)
# So	 the	 way	 that	 we	 can	 kind	 of	 get	 some	 of	 these	 details	 through	 patients	 is	 good
# communication.	So	really	just	kind	of	talking	with	them	and	seeing	where	their	concerns	may	or
# may	not	lie.	Just	really	observing	the	patient	accurately,	looking	through	the	patient	record	and
# history.
# (2:16	-	2:36)
# Is	this	their	first	surgery	ever?	Have	they	been	through	a	lot	of	really	difficult	surgeries	before?
# And	maybe	they're	kind	of	struggling	a	little	bit.	And	then	also	getting	information	from	others.
# So	other	providers	that	maybe	are	familiar	with	this	patient	or	other	caregivers	that	are
# History	of	Surgical	Technology
# (0:08	-	0:20)
# Hello	everyone,	and	welcome	back	to	our	channel.	A	while	ago,	we	made	a	video	on	the	history
# of	surgery.	If	you	haven't	watched	that,	go	do	it	after	this,	which	you	all	loved,	so	we	thought
# we'd	make	more	surgery-related	content	for	you	guys.
# (0:21	-	0:32)
# That	is	why	today	we	have	a	video	on	the	history	of	surgical	technology.	It's	all	stupid
# interesting,	and	we'll	be	talking	about	a	role	in	hospitals	that	is	so	important,	but	also	so
# underrated.	So,	let's	begin.
# (0:33	-	0:48)
# To	the	operating	theatre,	don't	forget	your	gloves.	What	is	surgical	technology?	To	start	off
# with,	let's	understand	what	surgical	technology	is.	You	might	hear	the	word	technology	and
# think	about	cool	gadgets	and	smart	systems,	but	that's	not	exactly	right.
# (0:48	-	1:07)
# Surgical	technology	is	a	field	of	medicine	studied	and	practised	by	health	professionals	who
# work	as	a	team	to	deliver	surgical	care.	Surgical	technologists,	also	known	as	surgical
# technicians,	or	more	commonly	as	scrubs,	remember	the	TV	show.	They	are	members	of	an
# operating	room	team	who	work	under	the	authority	of	a	surgeon.
# (1:07	-	1:28)
# They're	part	of	a	five-member	team	which	includes	a	circulating	nurse,	surgical	resident	or	first
# assistant,	an	anesthesiologist,	and	of	course	the	surgeon.	These	technologists	have	a	number
# of	different	roles	and	responsibilities,	and	we'll	quickly	go	over	them	before	we	get	into	the
# history	of	their	profession.	Surgical	technologists	are	crucial	at	every	step	of	the	surgery
# process.
# (1:29	-	2:06)
# Before	surgery,	some	of	their	duties	may	include	cleaning	wounds	with	surgical	antiseptics,
# such	as	chlorhexidine	or	povidone	iodine,	and	surgically	skin	prepping	the	area	of	the	body
# where	surgery	is	to	be	performed	with	70%	alcohol	or	some	other	chlorhexidine-based
# solution,	as	well	as	setting	up	the	operating	room	with	surgical	instrumentation,	supplies,
# medication,	and	all	necessary	equipment.	In	the	OR,	surgical	technologist	and	everyone	else
# wears	personal	protective	equipment,	PPE,	like	surgical	gowns,	masks,	and	surgical	caps.
# They'd	also	aid	the	surgeon	with	dunning	or	attire	such	as	gowns	and	gloves.
# Bank Name: nan Question: Because of the legal implications of this document, it must be signed by the physician, the patient, and a witness. This document is called a(n) __________________. Without this signed document, surgery cannot proceed. Randomization (Yes/No): Yes Correct Answer Number: 2 Answer 1: Surgical Count Sheet Feedback 1: nan Answer 2: informed consent Feedback 2: nan Answer 3: advance directive Feedback 3: nan Answer 4: operative record Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Course Name: Introduction to Surgical Technology File Name: Chapter 1 (Introduction to Surgical Technology)
#  Topic: Chapter 1: Introduction to Surgical Technology
#  Description: Explore the origins, training, and role of surgical technologists,
# the services provided by their professional association, career
# opportunities, and the ethics and behaviors defining the field. Keywords: Surgical Technology, Surgical Technologist, AST, Operating Room, Sterile Team, Certification, Surgical Assisting, Healthcare Careers, Ethics, Professionalism​
# Course Name: Introduction to Surgical Technology File Name: Chapter 05 (Supporting The Psychosocial
# Needs Of The Patient)
#
#
#
#  Topic: Chapter 05: Supporting The Psychosocial
# Needs Of The Patient
#
#
#
#  Description: Define patient-centered and outcome-oriented care, understand
# human needs based on Maslow’s hierarchy and Roger’s theory,
# recognize preoperative patient fears, the role of spirituality, and
# psychosocial care for special needs patients in the perioperative
feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Course Name: Introduction to Surgical Technology File Name: Lesson - 02 Communication and Teamwork Topic: Communication and Teamwork Description: Examine critical elements and barriers of effective communication, types of verbal abuse, problematic workplace behaviors, teamwork, and the utilization of computers in the
# perioperative environment. Keywords: Communication, Teamwork, Verbal Communication, Non-Verbal Communication, Cultural Competence, Conflict Resolution, Active Listening, Patient Safety, Workplace Behavior, Surgical Team​
# Bank Name: nan Question: Performing a surgical procedure on an individual without obtaining informed consent, in a non-emergency situation could be considered _____________. Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: Assault and Battery Feedback 1: nan Answer 2: Abandonment Feedback 2: nan Answer 3: Slander Feedback 3: nan Answer 4: Defamation Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Course Name: Introduction to Surgical Technology File Name: Lesson - 01 Quiz
#  Topic: Introduction to Surgical Technology
#  Description: Explore the origins, training, and role of surgical technologists,
# the services provided by their professional association, career
# opportunities, and the ethics and behaviors defining the field. Keywords: nan
# TECHNOLOGYSURGICAL
# Health Tech Academy’s guide to become a certified Surgical Technologist
# INTRODUCTION TO
# TECHNOLOGYSURGICAL
# Health Tech Academy’s guide to become a certified Surgical Technologist
# INTRODUCTION TO
# TECHNOLOGYSURGICAL
# Health Tech Academy’s guide to become a certified Surgical Technologist
# INTRODUCTION TO
# TECHNOLOGYSURGICAL
# Health Tech Academy’s guide to become a certified Surgical Technologist
# INTRODUCTION TO
# TECHNOLOGYSURGICAL
# Health Tech Academy’s guide to become a certified Surgical Technologist
# INTRODUCTION TO
# Bank Name: nan Question: The Need for surgical assistants first arose during _______. Randomization (Yes/No): Yes Correct Answer Number: 2 Answer 1: The American Civil War Feedback 1: nan Answer 2: WWII Feedback 2: nan Answer 3: The Korean War Feedback 3: nan Answer 4: None are Correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Course Name: Introduction to Surgical Technology File Name: Lesson - 05 Quiz
#  Topic: Supporting The Psychosocial
# Needs Of The Patient
#
#
#
#  Description: Define patient-centered and outcome-oriented care, understand
# human needs based on Maslow’s hierarchy and Roger’s theory,
# recognize preoperative patient fears, the role of spirituality, and
# psychosocial care for special needs patients in the perioperative
# environment. Keywords: nan
# Course Name: Introduction to Surgical Technology File Name: C1L4 Topic: Healthcare facility structure and environment Description: This lesson covers the structure and environment of healthcare facilities, focusing on operating room design, infection control, and efficiency. It highlights different facility layouts, surgical equipment, and furniture, emphasizing their roles in patient safety, workflow optimization, and maintaining sterile conditions. Keywords: healthcare facility, operating room design, infection control, sterile environment, surgical equipment, efficiency, perioperative care, surgical tables, workflow optimization, patient safety
# What	is	a	SURGICAL	TECHNOLOGIST?
# (0:00	-	0:20)
# Hey	guys,	welcome	back	to	another	Surgical	Tech	Tips.	Today	I	wanted	to,	I	really	wanted	to
# make	a	video	that	shines	a	light	on	surgical	technologists	and	really	brings	to	light	what	we	do.
# And	I	really,	really	hope	that	I	can	capture	that	in	this	short	little	video.
# (0:21	-	0:52)
# I	hope	you	enjoy	it.	What	is	a	surgical	technologist?	In	short,	we	help	out	surgeons	during
# surgery,	but	if	you	want	a	more	in-depth	look	into	our	jobs,	keep	watching.	One	of	the	first	and
# most	common	misconceptions	of	the	surgical	technologist	is	that	they're	all	nurses,	when	in
# fact	they're	not.
# (0:52	-	1:10)
# Some	people	may	refer	to	them	as	scrub	nurses,	but	we	are	not	registered	nurses.	We	are
# certified	surgical	techs.	The	training	that	the	surgical	technologist	goes	through	is	very
# specified	to	the	operating	room	and	things	related	to	the	operating	room	themselves.
# (1:10	-	1:33)
# As	a	nurse,	you're	trained	in	a	vast	array	of	clinical	areas	and	it's	nowhere	very	specific.	The
# surgical	technologist	is	specific	to	the	operating	room.	We	are	trained	in	opening	and	setting
# up	a	sterile	field	in	the	OR	for	the	procedures	at	hand.
# (1:33	-	2:03)
# We're	in	charge	of	maintaining	that	sterility	throughout	the	entire	case	and	ensuring	that
# there's	no	breaks	in	sterile	technique	for	other	members	at	the	surgical	field.	We	have	a	deep
# understanding	of	the	surgical	procedures	that	we	help	perform.	We	are	standing	hand-in-hand
# with	the	surgeon,	assisting	in	surgery,	passing	instruments,	sutures,	and	any	other	devices	that
# the	surgeon	may	need	throughout	a	procedure.
# (2:04	-	2:40)
# Other	times,	we	may	be	actually	assisting	that	surgeon	with	retracting	tissue	and	helping	out
# throughout	the	procedure.	Our	jobs	in	the	OR	revolve	around	excellence	in	patient	care,	with
# our	association's	motto	being	agar	primo,	which	in	English	means	the	patient	first.	When	it
# comes	to	the	operating	room,	you	may	have	one	surgeon	fixing	you,	but	it	takes	a	team	to	see
# it	through	from	start	to	finish,	and	a	surgical	technologist	is	an	integral	member	of	that	team.
# (3:02	-	3:04)
# For	more	information,	visit	www.FEMA.gov
# Course Name: Introduction to Surgical Technology File Name:
# Chapter 04 (Health Care Facility Structure
# And Environment)
#
#  Topic:
# Chapter 04: Health Care Facility Structure
# And Environment
#
#  Description: Understand operating room design, common items and work areas in
# the surgical suite, hospital ancillary services, ambulatory surgery
# facilities, healthcare insurance, chain of command, and roles of
# perioperative professionals Keywords: Operating Room Design, Perioperative Environment, Sterile Processing, Airflow Ventilation, Ambulatory Surgery, Hospital Accreditation, Surgical Suite, OR Equipment, Surgical Safety, Regulatory Standards​Chapter 4 (Health Care …
# Bank Name: nan Question: In patient-centered care, the surgical team bases assessment, planning, and intervention on the unique needs of the ________. Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: Patient Feedback 1: nan Answer 2: Surgical Technologist Feedback 2: nan Answer 3: Surgeon Feedback 3: nan Answer 4: Hospital CEO Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Course Name: Introduction to Surgical Technology File Name:
# Lesson - 04 Health Care Facility Structure
# And Environment
#
#  Topic:
# Health Care Facility Structure
# And Environment
#
#  Description: Understand operating room design, common items and work areas in the surgical suite, hospital ancillary services, ambulatory surgery facilities, healthcare insurance, chain of command, and roles of perioperative professionals Keywords: Operating Room Design, Perioperative Environment, Sterile Processing, Airflow Ventilation, Ambulatory Surgery, Hospital Accreditation, Surgical Suite, OR Equipment, Surgical Safety, Regulatory Standards​
# Bank Name: nan Question: Surgical technologists are trained in __________. Randomization (Yes/No): Yes Correct Answer Number: 4 Answer 1: 2-year colleges Feedback 1: nan Answer 2: Military Feedback 2: nan Answer 3: Certificate Programs Feedback 3: nan Answer 4: All are correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The surgical department is structured and engineered to provide a safe and efficient environment for patients and staff members. Many different designs can be used, but all must achieve the following objective(s). Randomization (Yes/No): No Correct Answer Number: 4 Answer 1: environmental safety Feedback 1: nan Answer 2: efficient use of personnel, time, space, and resources Feedback 2: nan Answer 3: Infection control Feedback 3: nan Answer 4: All are correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The team member ultimately responsible for overall care of the patient and surgical procedure is the __________ Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: Attending Surgeon Feedback 1: nan Answer 2: Circulator Feedback 2: nan Answer 3: Scrub Feedback 3: nan Answer 4: Anesthesiologist Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Course Name: Introduction to Surgical Technology File Name: Lesson - 04 Quiz
#  Topic:
# Health Care Facility Structure
# And Environment
#
#  Description: Understand operating room design, common items and work areas in
# the surgical suite, hospital ancillary services, ambulatory surgery
# facilities, healthcare insurance, chain of command, and roles of
# perioperative professionals Keywords: nan
# Bank Name: nan Question: The non-sterile member of the surgical team responsible for opening new sterile supplies, instruments, and implants during surgery is the ________ Randomization (Yes/No): Yes Correct Answer Number: 4 Answer 1: Scrub Feedback 1: nan Answer 2: First Assistant Feedback 2: nan Answer 3: Anesthestist Feedback 3: nan Answer 4: Circulator Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Course Name: Introduction to Surgical Technology File Name: Lesson - 02 Quiz
#  Topic: Communication and Teamwork Description: Examine critical elements and barriers of effective
# communication, types of verbal abuse, problematic workplace
# behaviors, teamwork, and the utilization of computers in the
# perioperative environment. Keywords: nan
# Bank Name: nan Question: One of the main strategies in the floor plan of a surgical department is __________. Randomization (Yes/No): No Correct Answer Number: 1 Answer 1: Infection Control Feedback 1: nan Answer 2: feng shui Feedback 2: nan Answer 3: open concept floor plans Feedback 3: nan Answer 4: None are Correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The nonsterile member of the surgical team is called __________. Randomization (Yes/No): Yes Correct Answer Number: 3 Answer 1: Assistant Feedback 1: nan Answer 2: Scrub Feedback 2: nan Answer 3: Circulator Feedback 3: nan Answer 4: Surgeon Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Certification for the surgical technologist is ________. Randomization (Yes/No): Yes Correct Answer Number: 2 Answer 1: mandatory Feedback 1: nan Answer 2: voluntary Feedback 2: nan Answer 3: unnecessary Feedback 3: nan Answer 4: invalid Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# C1L4	-	Ashley	Hay(1)
# (0:05	-	0:29)
# Welcome	back.	So,	in	this	lesson,	we	looked	at	healthcare	facility	structure	and	environment.
# So,	a	few	key	takeaways	from	that	are	just	kind	of	knowing	the	difference,	right?	So,	what	does
# structure	look	like?	Things	like	layout	and	design	elements	versus	environment,	which	might	be
# overall	surroundings,	cleanliness,	air	quality,	noise	levels,	things	like	that.
# (0:30	-	1:18)
# And	in	some	of	the	lesson	objectives,	as	you've	now	gone	through	this	module,	you	want	to	just
# kind	of	think	about	the	principles	of	operating	room	design	and	the	differences	that	you	might
# see	in	different	surgical	operating	suites,	in	different	settings,	different	facilities,	and	then	think
# about	what	might	some	common	items	be	that	you	might	find	in	a	surgical	suite?	What	could,
# how	could	they	differ?	Think	about	maybe	the	functions	of	different	work	areas	in	that	surgical
# suite	in	particular.	So,	maybe	a	setup	area	versus	a	cleanup	area.	And	then	also	considering
# some	common	ancillary	services	and	describing	their	functions,	right?	So,	things	like
# housekeeping	or,	you	know,	delivery	of	certain	surgical	items.
# (1:19	-	3:46)
# And	then	I	also	want	you	to	be	able	to	think	about	advantages	and	disadvantages	of	different
# types	of	surgical	facilities	and	ambulatory	ones	in	particular.	So,	ambulatory	is	basically	another
# way	of	saying	outpatient.	And	then	you	also	want	to	be	able	to	identify	just	different
# professionals	in	the	perioperative	space	and	what	their	roles	might	be.
# And	so,	when	we	go	back	to	thinking	about,	you	know,	operating	room	design,	the
# environment,	the	surroundings,	and	also	the	structure,	we	want	to	think	about	why	those
# different	design	elements	exist,	right?	So,	an	operating	room,	it's	designed	to	be	able	to	create
# and	establish	certain	zones	to	prevent	the	transmission	of	infection	and	different	kinds	of
# microorganisms	that	could	be	infectious.	So,	when	we	think	about	OR	design,	some	of	the	main
# objectives	that	we	want	to	be	sure	that	we're	aware	of,	one	is	infection	control.	Absolutely
# imperative.
# So,	we	want	to	always	think	in	any	time	that	we're	in	the	operating	suite	about	physical
# separation	between	the	surgical	environment	and	any	source	of	contamination.	And	then	think
# about	what	sources	of	contamination	or	infection	might	be	present	that	we	want	to	prevent
# from	getting	into	the	OR	suite.	So,	thinking	about,	you	know,	things	like	when	we	get	deliveries
# of	certain	surgical	instruments,	how	do	they	need	to	be	prepared	or	maybe	taken	out	of	certain
# packages?	Do	they	need	to	be	sterilised?	Kind	of	what	is	your	hospital's	policies	and	procedures
# there?	Another	objective	of	designing	an	OR	is	environmental	safety.
# So,	there	are	certain	standards	that	have	to	be	met	for	things	like	electricity	or	gas,	oxygen,
# Bank Name: nan Question: The Certification titles for Surgical Technologists are ______ and ______ Randomization (Yes/No): Yes Correct Answer Number: 2 Answer 1: AST, CNOR Feedback 1: nan Answer 2: CST, TS-C Feedback 2: nan Answer 3: NBSTSA, STC Feedback 3: nan Answer 4: CCRN, PCA Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# C1L1	-	Ashley	Hay
# (0:05	-	5:41)
# Hello,	welcome	back.	So	we	already	just	kind	of	briefly	covered	the	introduction	to	what	this
# course	might	include,	but	now	I	would	like	to	just	go	and	dive	in	a	little	bit	deeper.	So	starting
# with	course	one,	lesson	one,	we	give	just	kind	of	a	brief	introduction	to	the	profession	of
# surgical	technology	and	what	that	will	look	like	for	you	as	a	professional.
# We	did	go	over	briefly	some	kind	of,	you	know,	just	the	history	of	the	profession	in	general,	and
# then	also	some	organisations.	And	while	I	think	the	history	of	how	the	surgical	technologist
# came	to	be	is	really	interesting	and	definitely	important	to	know,	you	know,	a	bit	of	your
# background	and	kind	of	what	you're	going	to	be	practising	and	how	all	of	that	came	about.	I
# also	think	that	the	professional	and	affiliate	organisations	that	we're	going	to	talk	about	today
# are	really	important	for	you	to	know	because	they	can	be	incredible	resources	for	you.
# So	being	able	to	reach	out	and,	you	know,	maybe	get	some	educational	references	that	you're
# interested	in	or	find	certain	scope	of	practise	areas,	continuing	education.	Often	these
# professional	organisations	also	put	on	different	kinds	of	meetings	and	symposiums,	things	like
# that.	So	just,	you	know,	big	get-togethers	every	year,	so	that	way	you	can	also	get	some
# continuing	ed	that	way	and	kind	of	network	with	some	of	your	peers.
# Okay,	so	here	we	see	just	a	few	logos	of	these	professional	and	affiliate	organisations	who	are
# available	to	help	you.	One	that	I'd	really	like	to	point	out	is	the	Association	of	Surgical
# Technologists.	That's	AST.
# That	one	is	right	here,	the	blue	and	black	logo.	So	this	is	a	specific	organisation	in	surgical
# technology.	They	provide	forums	for	learning,	discussion	and	advocacy,	as	well	as	training	and
# curriculum	development,	and	they	advocate	for	standards	in	patient	care.
# So	looking	at	all	that	this	organisation	has	to	offer	is	definitely	helpful	to	you.	You	should
# definitely,	you	know,	visit	their	website	and	see	what	they	have	to	offer.	And	then	there's	a	few
# other	ones	here.
# The	National	Board	of	Surgical	Technology	and	Surgical	Assisting,	that's	abbreviated	NBSTSA,
# and	that's	this	first	one	on	the	left	here,	the	blue	and	red	icon,	and	they	are	a	certifying	body
# really	for	surgical	tech.	There's	certain	centres	for	testing,	the	NCCT,	National	Centre	for
# Competency	Testing,	and	then	there's	just	a	few	of	these	here	that	I	think	will	be	helpful	to	you.
# But	definitely,	you	know,	if	I	had	to	only	pick	one	or	two,	I	would	say	AST	and	the	National
# Board	of	SurgTech	would	be	kind	of	your	best	options	to	just	kind	of	start	your	learning	journey
# there	and	see	what	those	are	all	about.
# I	know	that	we	talked	a	little	bit	about	what	you	might	be	expected	to	do	in	the	field	of,	you
# know,	surgical	technology.	I	think	it's	important	to	know	that	the	Joint	Commission	defines	your
# Course Name: Introduction to Surgical Technology File Name: Exam 01 Topic: nan Description: nan Keywords: nan
# Bank Name: nan Question: Good communication clarifies relationships and helps establish professional and social boundaries. It increases teamwork and goals, which will greatly increase the safety of the environment for the ________. Randomization (Yes/No): Yes Correct Answer Number: 4 Answer 1: surgeons Feedback 1: nan Answer 2: management Feedback 2: nan Answer 3: acillary departments Feedback 3: nan Answer 4: patient Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Certification for surgical technologists is offered from these two organizations ______ and _______ Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: NBSTSA, NCCT Feedback 1: nan Answer 2: AST, AORN Feedback 2: nan Answer 3: CST, CAAHEP Feedback 3: nan Answer 4: JCAHO, CDC Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The professional association for surgical technologists is the ________ Randomization (Yes/No): Yes Correct Answer Number: 3 Answer 1: Association of periOperative Registered Nurse Feedback 1: nan Answer 2: American College of Surgeons Feedback 2: nan Answer 3: Association of Surgical Technologists Feedback 3: nan Answer 4: Accreditation Review Committee on Education in Surgical Technology Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Which of the following organizations oversees certification and credentialing for the surgical technologist? Randomization (Yes/No): Yes Correct Answer Number: 3 Answer 1: AORN Feedback 1: nan Answer 2: AST Feedback 2: nan Answer 3: NBSTSA Feedback 3: nan Answer 4: CAAHEP Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The portion of Universal Protocol conducted immediately prior to incision as a last check is known as the ________ Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: Surgical Time-Out Feedback 1: nan Answer 2: Informed Consent Feedback 2: nan Answer 3: Operative Checklist Feedback 3: nan Answer 4: Point of No Return Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The surgical technologist who works in a hospital or other facility that provides 24-hour care is usually required to __________. Randomization (Yes/No): Yes Correct Answer Number: 3 Answer 1: take a break every hour Feedback 1: nan Answer 2: do nothing Feedback 2: nan Answer 3: be "on call" Feedback 3: nan Answer 4: None are Correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Knowledge of the different __________ of children helps the surgical technologist understand the behaviors exhibited by these patients in the operating room. Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: Developmental Stages Feedback 1: nan Answer 2: Family Backgrounds Feedback 2: nan Answer 3: favorite toys Feedback 3: nan Answer 4: favorite foods Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: This is the peice of OR furniture that the patient is positioned on during surgery Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: The OR Bed Feedback 1: nan Answer 2: Prep Stand Feedback 2: nan Answer 3: Back Table Feedback 3: nan Answer 4: Double Ring Stand Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: AST is the ______ for Surgical Technologists Randomization (Yes/No): Yes Correct Answer Number: 3 Answer 1: Scholarly Journal Feedback 1: nan Answer 2: Online Discussion Board Feedback 2: nan Answer 3: Professional association Feedback 3: nan Answer 4: Social Network Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Which piece of equipment is designed to contain sterile basins that are used during surgery? Randomization (Yes/No): Yes Correct Answer Number: 3 Answer 1: Prep Stand Feedback 1: nan Answer 2: Mayo Stand Feedback 2: nan Answer 3: Ring Stand Feedback 3: nan Answer 4: Kick Bucket Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: This peice of OR furniture has a special drape which makes it sterile underneath, so it can be placed over the patient during surgery Randomization (Yes/No): Yes Correct Answer Number: 2 Answer 1: Prep Stand Feedback 1: nan Answer 2: Mayo Stand Feedback 2: nan Answer 3: Kick Bucket Feedback 3: nan Answer 4: Diving Board Table Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The Association of Surgical Technologists manages and sets_________. Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1:
feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The Scrub Person is responsible for _______. Randomization (Yes/No): Yes Correct Answer Number: 4 Answer 1: Setting up and maintaining sterile field Feedback 1: nan Answer 2: Passing Instruments to the Surgeon Feedback 2: nan Answer 3: Gowning and gloving surgical team members Feedback 3: nan Answer 4: All are correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The sterile team member responsible for all instrumentation and setting up the sterile field is the _______. Randomization (Yes/No): Yes Correct Answer Number: 2 Answer 1: Circulator Feedback 1: nan Answer 2: Scrub Feedback 2: nan Answer 3: Surgeon Feedback 3: nan Answer 4: Sterile Processing Tech Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Supporting the Psychosocial
# Needs of the Patient
# Health Care Facility
# Structure and Environment
# Bank Name: nan Question: The team member primarily responsible for monitoring the patient's vital signs, ensuring they stay asleep and are pain free is known as ___________ Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: The Anesthesiologist Feedback 1: nan Answer 2: The Circulator Feedback 2: nan Answer 3: Environmental Services (EVS) Feedback 3: nan Answer 4: None are correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: A(n) ___________ is an unexpected occurrence involving death or serious psychological injury, or risk thereof. It is titled as such because it signals the need for immediate investigation and response. Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: sentinel event Feedback 1: nan Answer 2: medical practice act Feedback 2: nan Answer 3: ethical dilemma Feedback 3: nan Answer 4: recommended practice Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: What statement is true about spiritual needs? Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: They are not necessarily religious Feedback 1: nan Answer 2: They are always the same as religious needs Feedback 2: nan Answer 3: Are the same for all patients of the same culture Feedback 3: nan Answer 4: should not be addressed Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# C1L3	-	Ashley	Hay
# (0:05	-	1:00)
# Hello,	welcome	back.	This	is	Ashley	Hay	with	Health	Tech	Academy	and	we	are	going	to	look	at
# some	legal	aspects	of	surgical	tech	and	kind	of	what	you	need	to	be	aware	of	professionally	and
# then	also	for	your	exam.	So	a	good	example	of	that,	you	know,	we	discuss	different	types	of	law
# in	health	and	just	law	in	general	and	we	talk	about	the	differences	briefly	just	between	federal
# and	state	law.
# And	I	think	it's	also	really	important	for	you	just	to	be	aware	of	what	kind	of	laws	exist	in	the
# state	that	you	are	going	to	be	practising	in.	Often	it'll	be	the	state	that	you	live	in.	So	it's	always
# important	to	be	at	least	aware	of	the	general	scope	of	practise	for	whatever	state	you	are	going
# to	be	practising	in.
# (1:01	-	1:54)
# So	I	think	stuff	like	that	is	helpful	for	you	professionally	to	be	aware	of	before	you	start	getting
# some	hands-on	training.	With	that	being	said,	there	were	a	lot	of	basic	legal	terms	that	we
# covered	in	the	module	and	I	think	it's	important	to	just	not	get	overwhelmed	by	them	for	your
# exam	but	know	that	it	is	possible	that	you	may	have	one	or	two	questions	related	to	those
# types	of	terms.	So	I	think	one,	just	knowing	the	examples	and	just	the	basic	differences,	just
# that	a	difference	exists	in	federal	law	versus	civil	law.
# And	so	an	example	of	that	would	be	like	federal	law	is	HIPAA,	which	we're	all	pretty	familiar
# with.	So	that's	the	Health	Insurance	Portability	and	Accountability	Act	that	went	into	practise	in
# 1996.	So	that's	something	at	the	federal	level.
# (1:55	-	3:54)
# And	then	civil	law	would	be	something	like	malpractice.	And	then	with	that,	some	of	those	basic
# legal	terms,	it	would	be	quite	surprising	if	a	term	like	bona	fide	or	certain	types	of	injury	law
# would	be	on	there	or	like	the	word	deposition,	as	those	are	quite	legal	in	focus.	So	you	want	to
# think	about	what	is	really	like	the	medical	legal,	so	the	medical	legal	terms	that	you	need	to	be
# aware	of.
# And	I	think	some	of	the	most	important	ones	for	that	would	be	knowing	things	like	just
# common	law	liability,	knowing	that	there's	corporate	liability	and	personal.	So	if	you	were
# ...
# So,	there	are	certain	standards	that	have	to	be	met	for	things	like	electricity	or	gas,	oxygen,
# Supporting the Psychosocial
# Needs of the Patient
# Bank Name: nan Question: Which piece of equipment is designed to contain sterile basins that are used during surgery? Randomization (Yes/No): Yes Correct Answer Number: 3 Answer 1: Prep Stand Feedback 1: nan Answer 2: Mayo Stand Feedback 2: nan Answer 3: Ring Stand Feedback 3: nan Answer 4: Kick Bucket Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: What are some common fears of patients in the OR setting? Randomization (Yes/No): No Correct Answer Number: 5 Answer 1: Pain Feedback 1: nan Answer 2: Death Feedback 2: nan Answer 3: Loss of Control Feedback 3: nan Answer 4: Disfigurement Feedback 4: nan Answer 5: All Are correct Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Surgical technologists are trained in __________. Randomization (Yes/No): Yes Correct Answer Number: 4 Answer 1: 2-year colleges Feedback 1: nan Answer 2: Military Feedback 2: nan Answer 3: Certificate Programs Feedback 3: nan Answer 4: All are correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Which of the following is a work area within the OR setting? Randomization (Yes/No): No Correct Answer Number: 5 Answer 1: OR Front Desk Feedback 1: nan Answer 2: Sterile Processing Department Feedback 2: nan Answer 3: Supply Room Feedback 3: nan Answer 4: Postanesthesia care unit (PACU) Feedback 4: nan Answer 5: All Are correct Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The portion of Universal Protocol conducted immediately prior to incision as a last check is known as the ________ Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: Surgical Time-Out Feedback 1: nan Answer 2: Informed Consent Feedback 2: nan Answer 3: Operative Checklist Feedback 3: nan Answer 4: Point of No Return Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The surgical consent is signed by the ________, __________, and a(n) ___________. Randomization (Yes/No): Yes Correct Answer Number: 3 Answer 1: Nurse, Surgeon, Scrub Feedback 1: nan Answer 2: Nurse, Surgeon, Anesthesiologist Feedback 2: nan Answer 3: Surgeon, Patient, Witness Feedback 3: nan Answer 4: Surgeon, Anesthesiologist, Nurse Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Poor patient care, errors, conflict, and stress are results of ________. Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: poor communication skills Feedback 1: nan Answer 2: aggression Feedback 2: nan Answer 3: lack of educated team members Feedback 3: nan Answer 4: cultural differences Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Law in most society is intended to protect __________. Randomization (Yes/No): No Correct Answer Number: 1 Answer 1: individuals Feedback 1: nan Answer 2: state officials Feedback 2: nan Answer 3: government officials Feedback 3: nan Answer 4: none are correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The Scrub Person is responsible for _______. Randomization (Yes/No): Yes Correct Answer Number: 4 Answer 1: Setting up and maintaining sterile field Feedback 1: nan Answer 2: Passing Instruments to the Surgeon Feedback 2: nan Answer 3: Gowning and gloving surgical team members Feedback 3: nan Answer 4: All are correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The surgical department is structured and engineered to provide a safe and efficient environment for patients and staff members. Many different designs can be used, but all must achieve the following objective(s). Randomization (Yes/No): No Correct Answer Number: 4 Answer 1: environmental safety Feedback 1: nan Answer 2: efficient use of personnel, time, space, and resources Feedback 2: nan Answer 3: Infection control Feedback 3: nan Answer 4: All are correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: All of the following are core principles of operating room design EXCEPT _____________. Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: Personnel Preferences Feedback 1: nan Answer 2: Infection Control Feedback 2: nan Answer 3: Environmental Safety Feedback 3: nan Answer 4: Efficiency Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Also called an Outpatient Center, a(n) __________  is a self-contained or freestanding facility that focuses on "day-surgery" meaning patients will go home after their procedures. Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: Ambulatory Surgery Facility Feedback 1: nan Answer 2: Sterile Processing Department Feedback 2: nan Answer 3: Nuclear Medicine Department Feedback 3: nan Answer 4: Trauma Bay Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: A(n) ___________ is an unexpected occurrence involving death or serious psychological injury, or risk thereof. It is titled as such because it signals the need for immediate investigation and response. Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: sentinel event Feedback 1: nan Answer 2: medical practice act Feedback 2: nan Answer 3: ethical dilemma Feedback 3: nan Answer 4: recommended practice Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Which piece of equipment is covered with a sterile drape and placed over the patient during the procedure for quick access to instruments? Randomization (Yes/No): Yes Correct Answer Number: 4 Answer 1: Ring Stand Feedback 1: nan Answer 2: Prep Stand Feedback 2: nan Answer 3: Kick Bucket Feedback 3: nan Answer 4: Mayo Stand Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Universal Protocol seeks to prevent ________ Randomization (Yes/No): No Correct Answer Number: 4 Answer 1: Wrong Patient Surgeries Feedback 1: nan Answer 2: Wrong Procedure Surgeries Feedback 2: nan Answer 3: Wrong Site Surgeries Feedback 3: nan Answer 4: All are correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Course Name: Introduction to Surgical Technology File Name: Lesson - 03 Quiz
#  Topic: Medicolegal Aspects Of Surgical
# Technology
#  Description: Learn to distinguish between laws, standards, and codes of
# conduct, understand risk management, licensure, and
# certification, recognize abuse and violence, define sentinel
# events, and explore negligence, documentation, informed
# consent, and legal documents in the perioperative environment. Keywords: nan
# Bank Name: nan Question: Because of the legal implications of this document, it must be signed by the physician, the patient, and a witness. This document is called a(n) __________________. Without this signed document, surgery cannot proceed. Randomization (Yes/No): Yes Correct Answer Number: 2 Answer 1: Surgical Count Sheet Feedback 1: nan Answer 2: informed consent Feedback 2: nan Answer 3: advance directive Feedback 3: nan Answer 4: operative record Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: What statement is true about spiritual needs? Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: They are not necessarily religious Feedback 1: nan Answer 2: They are always the same as religious needs Feedback 2: nan Answer 3: Are the same for all patients of the same culture Feedback 3: nan Answer 4: should not be addressed Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Surgery is performed by __________. Randomization (Yes/No): Yes Correct Answer Number: 4 Answer 1: surgeons Feedback 1: nan Answer 2: nurses Feedback 2: nan Answer 3: surgical technologists Feedback 3: nan Answer 4: teams of healthcare professionals Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: ___________ is the primary accreditation organization for all health care facilities. Randomization (Yes/No): No Correct Answer Number: 2 Answer 1: Occupational Safety and Health Administration (OSHA) Feedback 1: nan Answer 2: The Joint Commission Feedback 2: nan Answer 3: NBSTSA Feedback 3: nan Answer 4: None are Correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Airflow that travels in straight lines, so that it continually moves air in a specific directions without turbulence is known as ___________ Randomization (Yes/No): Yes Correct Answer Number: 2 Answer 1: Atmospheric CFM Feedback 1: nan Answer 2: Laminar Air Flow Feedback 2: nan Answer 3: Static Pressure Feedback 3: nan Answer 4: Directional Decontamination Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Which piece of equipment is covered with a removable mattress pad? Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: Operating Room Table Feedback 1: nan Answer 2: Mayo Stand Feedback 2: nan Answer 3: Ring Stand Feedback 3: nan Answer 4: Prep Stand Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: ________ are performed by two people during any surgery in which an item can be lost inside the patient. Randomization (Yes/No): Yes Correct Answer Number: 4 Answer 1: X-Rays Feedback 1: nan Answer 2: Extra precautions Feedback 2: nan Answer 3: negligence acts Feedback 3: nan Answer 4: surgical counts Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Negligence committed by a professional who deliberately acts outside of her or his scope of practice, or while impaired, is known as ________. Randomization (Yes/No): Yes Correct Answer Number: 2 Answer 1: damages Feedback 1: nan Answer 2: malpractice Feedback 2: nan Answer 3: a sentinel event Feedback 3: nan Answer 4: compaint Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The sterile team member responsible for all instrumentation and setting up the sterile field is the _______. Randomization (Yes/No): Yes Correct Answer Number: 2 Answer 1: Circulator Feedback 1: nan Answer 2: Scrub Feedback 2: nan Answer 3: Surgeon Feedback 3: nan Answer 4: Sterile Processing Tech Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Certification for the surgical technologist is ________. Randomization (Yes/No): Yes Correct Answer Number: 2 Answer 1: mandatory Feedback 1: nan Answer 2: voluntary Feedback 2: nan Answer 3: unnecessary Feedback 3: nan Answer 4: invalid Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Medicolegal Aspects of
# Surgical Technology
# Bank Name: nan Question: A legal document stating the patient’s wishes for refusing or limiting care if the patient becomes incompetent is known as a(n) ____________. Randomization (Yes/No): Yes Correct Answer Number: 2 Answer 1: nurse practice act Feedback 1: nan Answer 2: advance directive Feedback 2: nan Answer 3: informed consent Feedback 3: nan Answer 4: code of ethics Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: How can patient fears be supported effectively? Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: Showing Empathy Feedback 1: nan Answer 2: Going as quickly as possible Feedback 2: nan Answer 3: Sedating the patient so they do not know what is going on Feedback 3: nan Answer 4: None are correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The Association of Surgical Technologists manages and sets_________. Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: Standards of Practice Feedback 1: nan Answer 2: Accreditation Requirements Feedback 2: nan Answer 3: Surgical Technology Certification Feedback 3: nan Answer 4: None are Correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: One of the main strategies in the floor plan of a surgical department is __________. Randomization (Yes/No): No Correct Answer Number: 1 Answer 1: Infection Control Feedback 1: nan Answer 2: feng shui Feedback 2: nan Answer 3: open concept floor plans Feedback 3: nan Answer 4: None are Correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The Certification titles for Surgical Technologists are ______ and ______ Randomization (Yes/No): Yes Correct Answer Number: 2 Answer 1: AST, CNOR Feedback 1: nan Answer 2: CST, TS-C Feedback 2: nan Answer 3: NBSTSA, STC Feedback 3: nan Answer 4: CCRN, PCA Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The operating room is set up so that it prevents _______. Randomization (Yes/No): Yes Correct Answer Number: 2 Answer 1: Learning Feedback 1: nan Answer 2: Infection Feedback 2: nan Answer 3: Aggressiveness Feedback 3: nan Answer 4: None are correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: A sentinel event is one that ______. Randomization (Yes/No): No Correct Answer Number: 4 Answer 1: Involves death or serious injury Feedback 1: nan Answer 2: requires immediate investigation and response Feedback 2: nan Answer 3: Puts a patient at risk for severe injury Feedback 3: nan Answer 4: All are correct Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Certification for surgical technologists is offered from these two organizations ______ and _______ Randomization (Yes/No): Yes Correct Answer Number: 1 Answer 1: NBSTSA, NCCT Feedback 1: nan Answer 2: AST, AORN Feedback 2: nan Answer 3: CST, CAAHEP Feedback 3: nan Answer 4: JCAHO, CDC Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: The professional association for surgical technologists is the ________ Randomization (Yes/No): Yes Correct Answer Number: 3 Answer 1: Association of periOperative Registered Nurse Feedback 1: nan Answer 2: American College of Surgeons Feedback 2: nan Answer 3: Association of Surgical Technologists Feedback 3: nan Answer 4: Accreditation Review Committee on Education in Surgical Technology Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Which of the following organizations oversees certification and credentialing for the surgical technologist? Randomization (Yes/No): Yes Correct Answer Number: 3 Answer 1: AORN Feedback 1: nan Answer 2: AST Feedback 2: nan Answer 3: NBSTSA Feedback 3: nan Answer 4: CAAHEP Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# Bank Name: nan Question: Suzie has taken the CST examination and passed. For Suzie to keep her certification without retaking the examination, she must do one of the following __________. Randomization (Yes/No): Yes Correct Answer Number: 2 Answer 1: attend the national conference Feedback 1: nan Answer 2: maintain continuing education (CE) credits Feedback 2: nan Answer 3: nothing Feedback 3: nan Answer 4: attend all state meetings Feedback 4: nan Answer 5: nan Feedback 5: nan Answer n: nan Feedback n: nan
# [Time Tracker] `query_groq` took 7.6822 seconds
# [Time Tracker] `count_tokens` took 0.9639 seconds
# Response Toke   ns: 527
# [Time Tracker] `process_user_query` took 21.6147 seconds
# [Time Tracker] `get_embedding` took 2.9237 seconds
# [Time Tracker] `query_pinecone` took 14.8479 seconds
